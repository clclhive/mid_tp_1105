# %% [markdown]
# # 공공데이터 분석 예제
# ## Public Data Analysis Example
#
# 이 노트북은 공공데이터 분석을 위한 예제입니다.

# %%
# 필요한 라이브러리 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정 (matplotlib)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# 프로젝트 모듈 임포트
import sys
sys.path.append('../src')

from data_loader import DataLoader
from data_processor import DataProcessor

# %%
# DataLoader 및 DataProcessor 초기화
loader = DataLoader(data_dir='../data')
processor = DataProcessor()

# %% [markdown]
# ## 1. 데이터 로드
# 공공데이터를 불러옵니다.

# %%
# 데이터 로드 예제
# df = loader.load_csv('sample_data.csv', data_type='sample')
# df.head()

# %% [markdown]
# ## 2. 데이터 전처리
# 데이터를 정제하고 전처리합니다.

# %%
# 데이터 정제 예제
# df_cleaned = processor.clean_data(df)
# df_cleaned.info()

# %% [markdown]
# ## 3. 데이터 분석
# 데이터를 분석하고 시각화합니다.

# %%
# 데이터 분석 및 시각화 예제
# plt.figure(figsize=(10, 6))
# plt.title('분석 결과')
# plt.show()
